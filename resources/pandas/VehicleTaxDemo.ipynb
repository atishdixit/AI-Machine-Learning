# %%
import pandas as pd

# %%
vehicleTaxData = pd.read_csv("vehicleTax.csv")

# %%
vehicleTaxData.head()
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
# 4    Surat              2  MOTOR CYCLE
#
#    Year  Month  Count   Amount
# 0  1989      8      1    144.0
# 1  1994      3      1     27.0
# 2  1997      3      2    144.0
# 3  1997      4    312  21230.0
# 4  1997      4    105   7022.0

# %%
vehicleTaxData.tail()
# Out:
#      CityName  VehicleTypeId  \
# 3821    Surat             37
# 3822    Surat             23
# 3823    Surat             34
# 3824    Surat             38
# 3825    Surat             44
#
#                                             Description  Year  Month  Count  \
# 3821                            CNG Fitted Four Wheeler  2025      2    510
# 3822                                           FORKLIFT  2025      3      1
# 3823                                  E - Three Wheeler  2025      3      8
# 3824  CNG Fitted Goods Vehiclers/more than three Whe...  2025      3     17
# 3825                             CNG FITTED MOTOR CYCLE  2025      3     29
#
#          Amount
# 3821  7883994.0
# 3822    43750.0
# 3823    22502.0
# 3824   114674.0
# 3825    57521.0

# %%
data = pd.DataFrame(vehicleTaxData)

# %%
data.head()
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
# 4    Surat              2  MOTOR CYCLE
#
#    Year  Month  Count   Amount
# 0  1989      8      1    144.0
# 1  1994      3      1     27.0
# 2  1997      3      2    144.0
# 3  1997      4    312  21230.0
# 4  1997      4    105   7022.0

# %%
data.head(2)
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
#
#    Year  Month  Count  Amount
# 0  1989      8      1   144.0
# 1  1994      3      1    27.0

# %%
data.tail(1)
# Out:
#      CityName  VehicleTypeId             Description  Year  Month  Count  \
# 3825    Surat             44  CNG FITTED MOTOR CYCLE  2025      3     29
#
#        Amount
# 3825  57521.0

# %%
data.head(100)
# Out:
#    CityName  VehicleTypeId                                    Description  \
# 0     Surat              1  MOPED/SCOOTER
# 1     Surat              2  MOTOR CYCLE
# 2     Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3     Surat              1  MOPED/SCOOTER
# 4     Surat              2  MOTOR CYCLE
# ..      ...            ...                                            ...
# 95    Surat             12                             TRAILER UPTO 2 TON
# 96    Surat              1  MOPED/SCOOTER
# 97    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 98    Surat              9  LOADING TRUCK/TEMPO/TRACTOR 2 TO 4 TON
# 99    Surat              1  MOPED/SCOOTER
#
#     Year  Month  Count   Amount
# 0   1989      8      1    144.0
# 1   1994      3      1     27.0
# 2   1997      3      2    144.0
# 3   1997      4    312  21230.0
# 4   1997      4    105   7022.0
# ..   ...    ...    ...      ...
# 95  2002      9      1    432.0
# ...

# %%
data['VehicleTypeId']
# Out:
# 21

# %%
data[['VehicleTypeId', 'CityName']]
# Out:
#       VehicleTypeId CityName
# 0                 1    Surat
# 1                 2    Surat
# 2                 4    Surat
# 3                 1    Surat
# 4                 2    Surat
# ...             ...      ...
# 3821             37    Surat
# 3822             23    Surat
# 3823             34    Surat
# 3824             38    Surat
# 3825             44    Surat
#
# [3826 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['CityName', 'VehicleTypeId', 'Description', 'Year', 'Month', 'Count',
#        'Amount'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=3826, step=1)

# %%
data.shape
# Out:
# (3826, 7)

# %%
data.size
# Out:
# 26782

# %%
data.Description
# Out:
# 0           MOPED/SCOOTER
# 1           MOTOR CYCLE
# 2                              PRIVATE MOTOR CAR/JEEP CAR
# 3           MOPED/SCOOTER
# 4           MOTOR CYCLE
#                               ...
# 3821                              CNG Fitted Four Wheeler
# 3822                                             FORKLIFT
# 3823                                    E - Three Wheeler
# 3824    CNG Fitted Goods Vehiclers/more than three Whe...
# 3825                               CNG FITTED MOTOR CYCLE
# Name: Description, Length: 3826, dtype: object

# %%
data.CityName
# Out:
# 0       Surat
# 1       Surat
# 2       Surat
# 3       Surat
# 4       Surat
#         ...
# 3821    Surat
# 3822    Surat
# 3823    Surat
# 3824    Surat
# 3825    Surat
# Name: CityName, Length: 3826, dtype: object

# %%
data.Year
# Out:
# 0       1989
# 1       1994
# 2       1997
# 3       1997
# 4       1997
#         ...
# 3821    2025
# 3822    2025
# 3823    2025
# 3824    2025
# 3825    2025
# Name: Year, Length: 3826, dtype: int64

# %%
data.empty
# Out:
# False

# %%
data.values
# Out:
# array([['Surat', 1, 'MOPED/SCOOTER                                ', ...,
#         8, 1, 144.0],
#        ['Surat', 2, 'MOTOR CYCLE                                  ', ...,
#         3, 1, 27.0],
#        ['Surat', 4, 'PRIVATE MOTOR CAR/JEEP CAR', ..., 3, 2, 144.0],
#        ...,
#        ['Surat', 34, 'E - Three Wheeler', ..., 3, 8, 22502.0],
#        ['Surat', 38,
#         'CNG Fitted Goods Vehiclers/more than three Wheeler', ..., 3, 17,
#         114674.0],
#        ['Surat', 44, 'CNG FITTED MOTOR CYCLE', ..., 3, 29, 57521.0]],
#       dtype=object)

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=3826, step=1),
#  Index(['CityName', 'VehicleTypeId', 'Description', 'Year', 'Month', 'Count',
#         'Amount'],
#        dtype='object')]

# %%
data.dtypes
# Out:
# CityName          object
# VehicleTypeId      int64
# Description       object
# Year               int64
# Month              int64
# Count              int64
# Amount           float64
# dtype: object

# %%
data.loc[2:10,]
# Out:
#    CityName  VehicleTypeId                                    Description  \
# 2     Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3     Surat              1  MOPED/SCOOTER
# 4     Surat              2  MOTOR CYCLE
# 5     Surat              3                                  AUTO RICKSHAW
# 6     Surat              9  LOADING TRUCK/TEMPO/TRACTOR 2 TO 4 TON
# 7     Surat             21                                          TEMPO
# 8     Surat              9  LOADING TRUCK/TEMPO/TRACTOR 2 TO 4 TON
# 9     Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 10    Surat             21                                          TEMPO
#
#     Year  Month  Count   Amount
# 2   1997      3      2    144.0
# 3   1997      4    312  21230.0
# 4   1997      4    105   7022.0
# 5   1997      6      5   1294.0
# 6   1997      6      3   1050.0
# 7   1997      6      3    468.0
# 8   1997      7      1    180.0
# 9   1997      8     56   5530.0
# ...

# %%
data.loc[2:10,['VehicleTypeId', 'Description']]
# Out:
#     VehicleTypeId                                    Description
# 2               4                     PRIVATE MOTOR CAR/JEEP CAR
# 3               1  MOPED/SCOOTER
# 4               2  MOTOR CYCLE
# 5               3                                  AUTO RICKSHAW
# 6               9  LOADING TRUCK/TEMPO/TRACTOR 2 TO 4 TON
# 7              21                                          TEMPO
# 8               9  LOADING TRUCK/TEMPO/TRACTOR 2 TO 4 TON
# 9               4                     PRIVATE MOTOR CAR/JEEP CAR
# 10             21                                          TEMPO

# %%
data.describe()
# Out:
#        VehicleTypeId         Year        Month         Count        Amount
# count    3826.000000  3826.000000  3826.000000   3826.000000  3.826000e+03
# mean       11.739676  2013.456090     6.404339    654.067956  2.990401e+06
# std        10.305868     8.263616     3.495337   1562.059125  1.077294e+07
# min         1.000000  1989.000000     1.000000      1.000000  0.000000e+00
# 25%         3.000000  2008.000000     3.000000      2.000000  9.561250e+03
# 50%         9.000000  2015.000000     6.000000     16.000000  9.495800e+04
# 75%        19.000000  2021.000000     9.000000    208.000000  8.994132e+05
# max        44.000000  2025.000000    12.000000  10143.000000  1.309929e+08

# %%
data.Amount.describe()
# Out:
# count    3.826000e+03
# mean     2.990401e+06
# std      1.077294e+07
# min      0.000000e+00
# 25%      9.561250e+03
# 50%      9.495800e+04
# 75%      8.994132e+05
# max      1.309929e+08
# Name: Amount, dtype: float64

# %%
data.Description.describe()
# Out:
# count                                              3826
# unique                                               43
# top       MOTOR CYCLE
# freq                                                340
# Name: Description, dtype: object

# %%
copyData = data.copy()

# %%
copyData.head()
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
# 4    Surat              2  MOTOR CYCLE
#
#    Year  Month  Count   Amount
# 0  1989      8      1    144.0
# 1  1994      3      1     27.0
# 2  1997      3      2    144.0
# 3  1997      4    312  21230.0
# 4  1997      4    105   7022.0

# %%
copy = data.drop(columns = ['CityName', 'Description'])

# %%
copy.head()
# Out:
#    VehicleTypeId  Year  Month  Count   Amount
# 0              1  1989      8      1    144.0
# 1              2  1994      3      1     27.0
# 2              4  1997      3      2    144.0
# 3              1  1997      4    312  21230.0
# 4              2  1997      4    105   7022.0

# %%
import numpy as np

# %%
data.Amount.size
# Out:
# 3826

# %%
value = np.arange(0,3826)

# %%
value
# Out:
# array([   0,    1,    2, ..., 3823, 3824, 3825])

# %%
data.head()
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
# 4    Surat              2  MOTOR CYCLE
#
#    Year  Month  Count  Amount
# 0  1989      8      1       0
# 1  1994      3      1       1
# 2  1997      3      2       2
# 3  1997      4    312       3
# 4  1997      4    105       4

# %%
data.size
# Out:
# 26782

# %%
data['Amount'] = value

# %%
data.head()
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
# 4    Surat              2  MOTOR CYCLE
#
#    Year  Month  Count  Amount
# 0  1989      8      1       0
# 1  1994      3      1       1
# 2  1997      3      2       2
# 3  1997      4    312       3
# 4  1997      4    105       4

# %%
data.Amount.size
# Out:
# 3826

# %%
rows = data.iloc[0:4]

# %%
rows
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
#
#    Year  Month  Count  Amount
# 0  1989      8      1       0
# 1  1994      3      1       1
# 2  1997      3      2       2
# 3  1997      4    312       3

# %%
newRow = data.iloc[0:10]

# %%
newRow
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
# 4    Surat              2  MOTOR CYCLE
# 5    Surat              3                                  AUTO RICKSHAW
# 6    Surat              9  LOADING TRUCK/TEMPO/TRACTOR 2 TO 4 TON
# 7    Surat             21                                          TEMPO
# 8    Surat              9  LOADING TRUCK/TEMPO/TRACTOR 2 TO 4 TON
# 9    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
#
#    Year  Month  Count  Amount
# 0  1989      8      1       0
# 1  1994      3      1       1
# 2  1997      3      2       2
# 3  1997      4    312       3
# 4  1997      4    105       4
# 5  1997      6      5       5
# 6  1997      6      3       6
# 7  1997      6      3       7
# ...

# %%
duplicatRow = rows._append(newRow)

# %%
duplicatRow.head(10)
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
# 4    Surat              2  MOTOR CYCLE
# 5    Surat              3                                  AUTO RICKSHAW
#
#    Year  Month  Count  Amount
# 0  1989      8      1       0
# 1  1994      3      1       1
# 2  1997      3      2       2
# 3  1997      4    312       3
# 0  1989      8      1       0
# 1  1994      3      1       1
# 2  1997      3      2       2
# 3  1997      4    312       3
# 4  1997      4    105       4
# 5  1997      6      5       5

# %%
duplicatRow.drop_duplicates().head(10)
# Out:
#   CityName  VehicleTypeId                                    Description  \
# 0    Surat              1  MOPED/SCOOTER
# 1    Surat              2  MOTOR CYCLE
# 2    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
# 3    Surat              1  MOPED/SCOOTER
# 4    Surat              2  MOTOR CYCLE
# 5    Surat              3                                  AUTO RICKSHAW
# 6    Surat              9  LOADING TRUCK/TEMPO/TRACTOR 2 TO 4 TON
# 7    Surat             21                                          TEMPO
# 8    Surat              9  LOADING TRUCK/TEMPO/TRACTOR 2 TO 4 TON
# 9    Surat              4                     PRIVATE MOTOR CAR/JEEP CAR
#
#    Year  Month  Count  Amount
# 0  1989      8      1       0
# 1  1994      3      1       1
# 2  1997      3      2       2
# 3  1997      4    312       3
# 4  1997      4    105       4
# 5  1997      6      5       5
# 6  1997      6      3       6
# 7  1997      6      3       7
# ...

# %%
# Setting column name
# Data consistency check
# On Hot Encoding

# %%
# Data Summurasion technique
