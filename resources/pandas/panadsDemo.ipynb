# %%
##In this example, we:
##Read the CSV file into a pandas DataFrame.
##Displayed the first few rows of the DataFrame to get an overview of the data.
##Calculated the total sales and revenue for each product.
##Added a new column for the average revenue per sale.
##Filtered the data to show only sales for 'Product A'.
##Created a bar plot to visualize the total sales for each product.

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('sales_data.csv')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#          Date    Product  Sales  Revenue
# 0  2025-01-01  Product A    100      500
# 1  2025-01-02  Product B    150      750
# 2  2025-01-03  Product C    200     1000
# 3  2025-01-04  Product A    120      600
# 4  2025-01-05  Product B    130      650

# %%
# Calculate total sales and revenue for each product
total_sales = df.groupby('Product')['Sales'].sum()
total_revenue = df.groupby('Product')['Revenue'].sum()

print("Total Sales:\n", total_sales)
print("Total Revenue:\n", total_revenue)
# Out:
# Total Sales:
#  Product
# Product A    220
# Product B    280
# Product C    200
# Name: Sales, dtype: int64
# Total Revenue:
#  Product
# Product A    1100
# Product B    1400
# Product C    1000
# Name: Revenue, dtype: int64

# %%
# Add a new column for the average revenue per sale
df['Avg_Revenue_Per_Sale'] = df['Revenue'] / df['Sales']

# Filter the data to show only sales for 'Product A'
product_a_sales = df[df['Product'] == 'Product A']

print("Product A Sales:\n", product_a_sales)
# Out:
# Product A Sales:
#           Date    Product  Sales  Revenue  Avg_Revenue_Per_Sale
# 0  2025-01-01  Product A    100      500                   5.0
# 3  2025-01-04  Product A    120      600                   5.0

# %%
# Plot total sales for each product
total_sales.plot(kind='bar')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.title('Total Sales by Product')
plt.show()
